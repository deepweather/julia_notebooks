# %%
using Pkg
Pkg.add("Example")
# Out:
#    Updating registry at `~/.julia/registries/General`
# ######################################################################### 100,0%
#   Resolving package versions...
#   Installed Example ─ v0.5.3
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [7876af07] + Example v0.5.3
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [7876af07] + Example v0.5.3

# %%
using Example
# Out:
# ┌ Info: Precompiling Example [7876af07-990d-54b4-ab0e-23690620f79a]
# └ @ Base loading.jl:1278

# %%
hello("it's me")
# Out:
# "Hello, it's me"

# %%
less(hello)
# Out:
# module Example
# export hello, domath
#
# """
#     hello(who::String)
#
# Return "Hello, `who`".
# """
# hello(who::String) = "Hello, $who"
#
# """
#     domath(x::Number)
#
# Return `x + 5`.
# """
# domath(x::Number) = x + 5
#
# end

# %%
Pkg.add("Colors")
# Out:
#   Resolving package versions...
#   Installed Reexport ────────── v1.0.0
#   Installed FixedPointNumbers ─ v0.8.4
#   Installed ColorTypes ──────── v0.10.9
#   Installed Colors ──────────── v0.12.6
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [5ae59095] + Colors v0.12.6
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [3da002f7] + ColorTypes v0.10.9
#   [5ae59095] + Colors v0.12.6
#   [53c48c17] + FixedPointNumbers v0.8.4
#   [189a3867] + Reexport v1.0.0
#   [37e2e46d] + LinearAlgebra
#   [2f01184e] + SparseArrays
#   [10745b16] + Statistics

# %%
using Colors
# Out:
# ┌ Info: Precompiling Colors [5ae59095-9a9b-59fe-a467-6f913c188581]
# └ @ Base loading.jl:1278

# %%
palette = distinguishable_colors(100)
# Out:
# 100-element Array{RGB{N0f8},1} with eltype RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.0,0.0,0.0)
#  RGB{N0f8}(1.0,1.0,0.455)
#  RGB{N0f8}(1.0,0.608,1.0)
#  RGB{N0f8}(0.0,0.827,1.0)
#  RGB{N0f8}(0.886,0.388,0.051)
#  RGB{N0f8}(0.0,0.494,0.0)
#  RGB{N0f8}(0.0,0.314,0.902)
#  RGB{N0f8}(0.675,0.0,0.278)
#  RGB{N0f8}(0.0,1.0,0.784)
#  RGB{N0f8}(0.0,0.392,0.408)
#  RGB{N0f8}(1.0,0.835,0.769)
#  RGB{N0f8}(0.424,0.322,0.0)
#  RGB{N0f8}(0.478,0.459,0.506)
#  ⋮
#  RGB{N0f8}(0.0,0.557,0.58)
#  RGB{N0f8}(0.792,0.675,0.318)
#  RGB{N0f8}(0.471,0.482,0.231)
#  RGB{N0f8}(0.714,0.976,0.851)
#  RGB{N0f8}(0.855,0.0,0.247)
#  RGB{N0f8}(0.18,0.129,0.141)
#  RGB{N0f8}(0.0,0.345,0.082)
#  RGB{N0f8}(1.0,0.557,0.114)
#  RGB{N0f8}(0.4,0.455,0.694)
#  RGB{N0f8}(0.0,0.804,0.678)
#  RGB{N0f8}(0.0,0.498,0.388)
#  RGB{N0f8}(0.6,0.435,0.239)

# %%
rand(palette, 20,20)
# Out:
# 20×20 Array{RGB{N0f8},2} with eltype RGB{FixedPointNumbers.Normed{UInt8,8}}:
#  RGB{N0f8}(0.953,1.0,0.98)     …  RGB{N0f8}(0.031,0.024,0.694)
#  RGB{N0f8}(0.0,0.804,0.678)       RGB{N0f8}(0.784,0.761,0.71)
#  RGB{N0f8}(0.694,0.863,0.988)     RGB{N0f8}(0.031,0.024,0.694)
#  RGB{N0f8}(0.812,0.831,0.992)     RGB{N0f8}(0.435,0.357,0.584)
#  RGB{N0f8}(0.0,0.804,0.678)       RGB{N0f8}(0.0,0.827,1.0)
#  RGB{N0f8}(0.0,0.498,0.388)    …  RGB{N0f8}(1.0,0.204,0.176)
#  RGB{N0f8}(0.0,0.827,1.0)         RGB{N0f8}(0.055,0.0,0.149)
#  RGB{N0f8}(0.282,0.361,0.0)       RGB{N0f8}(0.0,0.557,0.58)
#  RGB{N0f8}(0.424,0.322,0.0)       RGB{N0f8}(0.267,0.267,0.224)
#  RGB{N0f8}(0.408,0.482,0.478)     RGB{N0f8}(1.0,0.608,1.0)
#  RGB{N0f8}(0.812,0.831,0.992)  …  RGB{N0f8}(0.0,0.471,0.89)
#  RGB{N0f8}(0.408,0.482,0.478)     RGB{N0f8}(0.0,0.561,0.714)
#  RGB{N0f8}(0.384,0.0,0.098)       RGB{N0f8}(0.0,0.804,0.678)
#  RGB{N0f8}(0.0,0.176,0.188)       RGB{N0f8}(0.0,1.0,0.784)
# ...
